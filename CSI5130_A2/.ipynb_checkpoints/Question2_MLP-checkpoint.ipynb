# %%
import numpy as np
import struct
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from torchvision import datasets, transforms
import time
import statistics
import sklearn.metrics
import seaborn as sns

# %%
mnist_training, mnist_testing = tf.keras.datasets.mnist.load_data()
training_data = np.float16(mnist_training[0])  # Returns np.array
training_labels = np.asarray(mnist_training[1], dtype=np.int32)
testing_data = np.float16(mnist_testing[0])  # Returns np.array
testing_labels = np.asarray(mnist_testing[1], dtype=np.int32)

# %%
feature_columns = [tf.feature_column.numeric_column("images", shape=[28, 28])]

train_input_fn = tf.compat.v1.estimator.inputs.numpy_input_fn(
    x={"images": training_data},
    y= training_labels,
    num_epochs = None,
    batch_size = 50,
    shuffle = True
)

test_input_fn = tf.compat.v1.estimator.inputs.numpy_input_fn(
    x = {"images": testing_data},
    y = testing_labels,
    num_epochs = 1,
    shuffle = False
)

# %%
def repeatedTrainingAndTesting(model_name, dropout, batch_normalization, M):
    
          
    classifier = tf.estimator.DNNClassifier(
        feature_columns = feature_columns,
        hidden_units = [100, 100],
        optimizer = 'Adam',
        n_classes = 10,
        dropout = dropout,
        model_dir="./models/"+model_name,
        batch_norm = batch_normalization
    )
    
    accuracies = []
    bestModel = None

    for i in range(M):
        
        totalTime = 0
        
        print('_______________________________________________________________________ M='+str(i+1))
        
        # TRAIN
        start_time = time.time()
        classifier.train(input_fn = train_input_fn, steps=5000)
        end_time = time.time()
        duration = end_time - start_time
        print("Training time: --- %s seconds ---" % (duration))
        totalTime += duration
        
        # TEST
        start_time = time.time()
        accuracy_score = classifier.evaluate(input_fn=test_input_fn)["accuracy"]
        print("Testing Accuracy: {0:f}%\n".format(accuracy_score*100))
        print("Testing time: --- %s seconds ---" % (duration))
        accuracies.append(accuracy_score)
        
        
        if accuracy_score == max(accuracies):
            bestModel = classifier
        
    return (totalTime, bestModel)

# %%
def evaluate(bestModel, fileName):
    
    Y_pred = list(bestModel.predict(input_fn = test_input_fn))
    
    Y_pred_class = []
    
    for i in range(len(Y_pred)):
        Y_pred_class.append( Y_pred[i]['class_ids'].item() )

    
    confusion_mtx = tf.math.confusion_matrix(testing_labels, Y_pred_class) 
    
    f1 = sklearn.metrics.f1_score(testing_labels, Y_pred_class, average='weighted')
    accuracy = sklearn.metrics.accuracy_score(testing_labels, Y_pred_class)
    
    print(accuracy)

    plt.figure(figsize=(10, 8))
    svm = sns.heatmap(confusion_mtx, annot=True, fmt='g')
    figure = svm.get_figure()   
    figure.savefig(fileName)
    
    return (f1, accuracy)

# %% [markdown]
# # MLP

# %%
m = 50

# %% [markdown]
# ## With Dropout, With Batch-Normalization

# %%
(time_DO_BN, bestModel_DO_BN) = repeatedTrainingAndTesting(model_name = "mlp_DO_BN", dropout = 0.2, batch_normalization = True, M=m)
(top_f1_DO_BN, top_accuracy_DO_BN) = evaluate(bestModel_DO_BN, 'outputs/MLP_heatmap_DO_BN.png')
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': './models/mlp_DO_BN', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# _______________________________________________________________________ M=1
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./models/mlp_DO_BN\model.ckpt-410000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 410000...
# INFO:tensorflow:Saving checkpoints for 410000 into ./models/mlp_DO_BN\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 410000...
# INFO:tensorflow:loss = 0.0021587436, step = 410000
# INFO:tensorflow:global_step/sec: 286.479
# INFO:tensorflow:loss = 0.0025853612, step = 410100 (0.351 sec)
# INFO:tensorflow:global_step/sec: 344.562
# INFO:tensorflow:loss = 0.007148018, step = 410200 (0.290 sec)
# INFO:tensorflow:global_step/sec:
seconds ---
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2022-09-29T13:39:17Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./models/MLP_BN\model.ckpt-270000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.49767s
# INFO:tensorflow:Finished evaluation at 2022-09-29-13:39:18
# INFO:tensorflow:Saving dict for global step 270000: accuracy = 0.9828, average_loss = 0.14349705, global_step = 270000, loss = 0.14190768
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 270000: ./models/MLP_BN\model.ckpt-270000
# Testing Accuracy: 98.280001%
#
# Testing time: --- 18.29545760154724 seconds ---
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./models/mlp_DO_BN\model.ckpt-415000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 0.9805

# %% [markdown]
# # With Dropout, Without Batch-Normalization

# %%
(time_DO, bestModel_DO) = repeatedTrainingAndTesting(model_name = "mlp_DO", dropout = 0.2, batch_normalization = False, M=m)
(top_f1_DO, top_accuracy_DO) = evaluate(bestModel_DO, 'outputs/MLP_heatmap_DO.png')
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': './models/mlp_DO', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# _______________________________________________________________________ M=1
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./models/mlp_DO\model.ckpt-265000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 265000...
# INFO:tensorflow:Saving checkpoints for 265000 into ./models/mlp_DO\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 265000...
# INFO:tensorflow:loss = 0.025800638, step = 265000
# INFO:tensorflow:global_step/sec: 388.631
# INFO:tensorflow:loss = 0.22933477, step = 265100 (0.261 sec)
# INFO:tensorflow:global_step/sec: 464.2
# INFO:tensorflow:loss = 0.20093489, step = 265200 (0.216 sec)
# INFO:tensorflow:global_step/sec: 459.94
# INFO:tensorflow:loss = 0.16074084, step = 265300 (0.216 sec)
# INFO:tensorflow:global_step/sec: 453.705
# INFO:tensorflow:loss = 0.08829468, step = 265400 (0.219 sec)
# INFO:tensorflow:global_step/sec: 464.2
# INFO:tensorflow:loss = 0.035283674, step = 265500 (0.215 sec)
# INFO:tensorflow:global_step/sec: 449.616
# INFO:tensorflow:loss = 0.18123986, step = 265600 (0.222 sec)
# INFO:tensorflow:global_step/sec: 460.972
# INFO:tensorflow:loss = 0.16712913, step = 265700 (0.217 sec)
# INFO:tensorflow:global_step/sec: 457.832
# INFO:tensorflow:loss = 0.05807785, step = 265800 (0.218 sec)
# INFO:tensorflow:global_step/sec: 462.064
# INFO:tensorflow:loss = 0.3869814, step = 265900 (0.216 sec)
# INFO:tensorflow:global_step/sec: 451.984
# INFO:tensorflow:loss = 0.42510852, step = 266000 (0.221 sec)
# INFO:tensorflow:global_step/sec: 453.694
# INFO:tensorflow:loss = 0.15164493, step = 266100 (0.220 sec)
# INFO:tensorflow:global_step/sec: 385.854
# INFO:tensorflow:loss = 0.1483995, step = 266200 (0.259 sec)
# INFO:tensorflow:global_step/sec: 443.66
# INFO:tensorflow:loss = 0.11159515, step = 266300 (0.225 sec)
# INFO:tensorflow:global_step/sec: 463.02
# INFO:tensorflow:loss = 0.019105773, step = 266400 (0.216 sec)
# INFO:tensorflow:global_step/sec: 468.598
# INFO:tensorflow:loss = 0.18588603, step = 266500 (0.214 sec)
# INFO:tensorflow:global_step/sec: 453.698
# INFO:tensorflow:loss = 0.03420089, step = 266600 (0.219 sec)
# INFO:tensorflow:global_step/sec: 451.655
# INFO:tensorflow:loss = 0.0641126, step = 266700 (0.222 sec)
# INFO:tensorflow:global_step/sec: 402.671
# INFO:tensorflow:loss = 0.16400243, step = 266800 (0.248 sec)
# INFO:tensorflow:global_step/sec: 417.791
# INFO:tensorflow:loss = 0.18777601, step = 266900 (0.239 sec)
# INFO:tensorflow:global_step/sec: 407.591
# INFO:tensorflow:loss = 0.079579, step = 267000 (0.246 sec)
# INFO:tensorflow:global_step/sec:
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 270000: ./models/mlp_DO\model.ckpt-270000
# Testing Accuracy: 95.829999%
#
# Testing time: --- 14.910265922546387 seconds ---
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./models/mlp_DO\model.ckpt-270000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 0.9583

# %% [markdown]
# # Without Dropout, Without Batch-Normalization

# %%
(time_none, bestModel_none) = repeatedTrainingAndTesting(model_name = "mlp_none", dropout = False, batch_normalization = False, M=m)
(top_f1_none, top_accuracy_none) = evaluate(bestModel_none, 'outputs/MLP_heatmap_none.png')
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': './models/mlp_none', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# _______________________________________________________________________ M=1
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./models/mlp_none\model.ckpt-265000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 265000...
# INFO:tensorflow:Saving checkpoints for 265000 into ./models/mlp_none\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 265000...
# INFO:tensorflow:loss = 0.0, step = 265000
# INFO:tensorflow:global_step/sec: 390.726
# INFO:tensorflow:loss = 0.0, step = 265100 (0.258 sec)
# INFO:tensorflow:global_step/sec: 449.632
# INFO:tensorflow:loss = 0.02841889, step = 265200 (0.224 sec)
# INFO:tensorflow:global_step/sec: 453.695
# INFO:tensorflow:loss = 1.430511e-08, step = 265300 (0.219 sec)
# INFO:tensorflow:global_step/sec: 453.686
# INFO:tensorflow:loss = 0.0, step = 265400 (0.220 sec)
# INFO:tensorflow:global_step/sec: 449.64
# INFO:tensorflow:loss = 0.0, step = 265500 (0.221 sec)
# INFO:tensorflow:global_step/sec: 455.763
# INFO:tensorflow:loss = 0.05209667, step = 265600 (0.219 sec)
# INFO:tensorflow:global_step/sec: 449.62
# INFO:tensorflow:loss = 6.77958e-06, step = 265700 (0.223 sec)
# INFO:tensorflow:global_step/sec: 457.028
# INFO:tensorflow:loss = 0.17594875, step = 265800 (0.218 sec)
# INFO:tensorflow:global_step/sec: 451.736
# INFO:tensorflow:loss = 0.0, step = 265900 (0.221 sec)
# INFO:tensorflow:global_step/sec: 462.063
# INFO:tensorflow:loss = 0.047491513, step = 266000 (0.217 sec)
# INFO:tensorflow:global_step/sec: 453.7
# INFO:tensorflow:loss = 0.0, step = 266100 (0.219 sec)
# INFO:tensorflow:global_step/sec: 445.632
# INFO:tensorflow:loss = 7.62938e-08, step = 266200 (0.224 sec)
# INFO:tensorflow:global_step/sec: 457.838
# INFO:tensorflow:loss = 6.914127e-08, step = 266300 (0.218 sec)
# INFO:tensorflow:global_step/sec: 449.622
# INFO:tensorflow:loss = 0.038808063, step = 266400 (0.223 sec)
# INFO:tensorflow:global_step/sec: 457.853
# INFO:tensorflow:loss = 0.012956491, step = 266500 (0.217 sec)
# INFO:tensorflow:global_step/sec: 434.059
# INFO:tensorflow:loss = 0.0, step = 266600 (0.232 sec)
# INFO:tensorflow:global_step/sec: 449.628
# INFO:tensorflow:loss = 2.3841844e-08, step = 266700 (0.221 sec)
# INFO:tensorflow:global_step/sec: 388.632
# INFO:tensorflow:loss = 0.012863517, step = 266800 (0.256 sec)
# INFO:tensorflow:global_step/sec: 453.699
# INFO:tensorflow:loss = 0.0, step = 266900 (0.220 sec)
# INFO:tensorflow:global_step/sec: 435.945
# INFO:tensorflow:loss = 2.7178767e-06, step = 267000 (0.229 sec)
# INFO:tensorflow:global_step/sec: 448.819
# INFO:tensorflow:loss = 0.021350231, step = 267100 (0.224 sec)
# INFO:tensorflow:global_step/sec: 457.838
# INFO:tensorflow:loss = 0.0, step = 267200 (0.217 sec)
# INFO:tensorflow:global_step/sec: 449.632
# INFO:tensorflow:loss = 0.038191758, step = 267300 (0.223 sec)
# INFO:tensorflow:global_step/sec: 449.631
# INFO:tensorflow:loss = 0.0, step = 267400 (0.221 sec)
# INFO:tensorflow:global_step/sec: 455.75
# INFO:tensorflow:loss = 6.8154906e-05, step = 267500 (0.220 sec)
# INFO:tensorflow:global_step/sec: 445.643
# INFO:tensorflow:loss = 0.008647946, step = 267600 (0.223 sec)
# INFO:tensorflow:global_step/sec: 455.76
# INFO:tensorflow:loss = 0.034905437, step = 267700 (0.219 sec)
# INFO:tensorflow:global_step/sec: 440.765
# INFO:tensorflow:loss = 4.982897e-07, step = 267800 (0.228 sec)
# INFO:tensorflow:global_step/sec: 451.651
# INFO:tensorflow:loss = 0.0, step = 267900 (0.223 sec)
# INFO:tensorflow:global_step/sec: 429.977
# INFO:tensorflow:loss = 4.768371e-09, step = 268000 (0.232 sec)
# INFO:tensorflow:global_step/sec: 468.54
# INFO:tensorflow:loss = 0.0, step = 268100 (0.211 sec)
# INFO:tensorflow:global_step/sec: 459.939
# INFO:tensorflow:loss = 9.146249e-05, step = 268200 (0.217 sec)
# INFO:tensorflow:global_step/sec: 416.048
# INFO:tensorflow:loss = 9.1074304e-07, step = 268300 (0.240 sec)
# INFO:tensorflow:global_step/sec: 443.663
# INFO:tensorflow:loss = 0.0, step = 268400 (0.226 sec)
# INFO:tensorflow:global_step/sec: 447.623
# INFO:tensorflow:loss = 0.0, step = 268500 (0.222 sec)
# INFO:tensorflow:global_step/sec: 461.907
# INFO:tensorflow:loss = 0.0, step = 268600 (0.216 sec)
# INFO:tensorflow:global_step/sec: 459.941
# INFO:tensorflow:loss = 0.0, step = 268700 (0.217 sec)
# INFO:tensorflow:global_step/sec: 451.656
# INFO:tensorflow:loss = 0.14830509, step = 268800 (0.221 sec)
# INFO:tensorflow:global_step/sec: 449.627
# INFO:tensorflow:loss = 0.035495304, step = 268900 (0.222 sec)
# INFO:tensorflow:global_step/sec: 445.633
# INFO:tensorflow:loss = 0.102772735, step = 269000 (0.224 sec)
# INFO:tensorflow:global_step/sec: 459.943
# INFO:tensorflow:loss = 1.430511e-08, step = 269100 (0.217 sec)
# INFO:tensorflow:global_step/sec: 447.94
# INFO:tensorflow:loss = 1.4305113e-08, step = 269200 (0.225 sec)
# INFO:tensorflow:global_step/sec: 479.756
# INFO:tensorflow:loss = 1.4304641e-06, step = 269300 (0.208 sec)
# INFO:tensorflow:global_step/sec: 475.196
# INFO:tensorflow:loss = 2.3841857e-09, step = 269400 (0.208 sec)
# INFO:tensorflow:global_step/sec: 468.535
# INFO:tensorflow:loss = 8.05217e-06, step = 269500 (0.214 sec)
# INFO:tensorflow:global_step/sec: 472.966
# INFO:tensorflow:loss = 0.0, step = 269600 (0.210 sec)
# INFO:tensorflow:global_step/sec: 470.741
# INFO:tensorflow:loss = 0.051395465, step = 269700 (0.213 sec)
# INFO:tensorflow:global_step/sec: 477.455
# INFO:tensorflow:loss = 0.051026475, step = 269800 (0.209 sec)
# INFO:tensorflow:global_step/sec: 476.039
# INFO:tensorflow:loss = 7.974494e-06, step = 269900 (0.209 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 270000...
# INFO:tensorflow:Saving checkpoints for 270000 into ./models/mlp_none\model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 270000...
# INFO:tensorflow:Loss for final step: 3.5285643e-07.
# Training time: --- 14.137133598327637 seconds ---
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2022-09-29T13:39:53Z
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./models/mlp_none\model.ckpt-270000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 0.41090s
# INFO:tensorflow:Finished evaluation at 2022-09-29-13:39:54
# INFO:tensorflow:Saving dict for global step 270000: accuracy = 0.9733, average_loss = 1.8527186, global_step = 270000, loss = 1.8321979
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 270000: ./models/mlp_none\model.ckpt-270000
# Testing Accuracy: 97.329998%
#
# Testing time: --- 14.137133598327637 seconds ---
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./models/mlp_none\model.ckpt-270000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# 0.9733

# %% [markdown]
# # Save Results

# %%
data = {'Accuracy_DO_BN': top_accuracy_DO_BN, 'Time_DO_BN': time_DO_BN,'F1_DO': top_f1_DO_BN,
        'Accuracy_BN' : top_accuracy_BN, 'Time_BN' : time_BN, 'F1_BN': top_f1_BN,
        'Accuracy_DO' : top_accuracy_DO, 'Time_DO': time_DO, 'F1_DO': top_f1_DO, 
        'Accuracy_NONE': top_accuracy_none, 'Time_NONE': time_none, 'F1_NONE' : top_f1_none}

df = pd.DataFrame(data,index=[0])

df.to_csv('outputs/MLP.csv')
